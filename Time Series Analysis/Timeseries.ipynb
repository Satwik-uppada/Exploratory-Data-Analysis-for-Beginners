# %% [markdown]
# # $$TimeSeries-Analysis$$

# %%
# TODO:
# Install yfinance

# !pip install  yfinance

# %%
import yfinance as yf
import pandas as pd 
from datetime import datetime

# %%
df_tesla = yf.download('TSLA')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-07-18  251.089996  257.140015  247.199997  249.229996  249.229996
# 2024-07-19  247.789993  249.440002  236.830002  239.199997  239.199997
# 2024-07-22  244.210007  253.210007  243.750000  251.509995  251.509995
# 2024-07-23  253.600006  255.759995  245.630005  246.380005  246.380005
# 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# 2010-07-02   77097000
# 2010-07-06  103003500
# ...               ...
# 2024-07-18  110869000
# 2024-07-19   87403900
# 2024-07-22  101225400
# 2024-07-23  111928200
# 2024-07-24  167234100
#
# [3541 rows x 6 columns]

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-07-18  251.089996  257.140015  247.199997  249.229996  249.229996
# 2024-07-19  247.789993  249.440002  236.830002  239.199997  239.199997
# 2024-07-22  244.210007  253.210007  243.750000  251.509995  251.509995
# 2024-07-23  253.600006  255.759995  245.630005  246.380005  246.380005
# 2024-07-24  225.419998  225.990005  214.710007  215.990005  215.990005
#
#                Volume
# Date
# 2024-07-18  110869000
# 2024-07-19   87403900
# 2024-07-22  101225400
# 2024-07-23  111928200
# 2024-07-24  167234100

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3541 entries, 2010-06-29 to 2024-07-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3541 non-null   float64
#  1   High       3541 non-null   float64
#  2   Low        3541 non-null   float64
#  3   Close      3541 non-null   float64
#  4   Adj Close  3541 non-null   float64
#  5   Volume     3541 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 322.7 KB

# %%
df_tesla['High'].plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit
df_tesla['High'].plot(figsize=(12,6),xlim = ['2020-01-01','2024-06-03'])
# Out:
# <Axes: xlabel='Date'>

# %%
## x limit and y limit
df_tesla['High'].plot(figsize=(12,6),xlim = ['2020-01-01','2024-06-03'],ylim=[0,500],c='red',ls='--')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## selecting particular range of dates from whole table

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-07-11', '2024-07-12', '2024-07-15', '2024-07-16',
#                '2024-07-17', '2024-07-18', '2024-07-19', '2024-07-22',
#                '2024-07-23', '2024-07-24'],
#               dtype='datetime64[ns]', name='Date', length=3541, freq=None)

# %%
index = df_tesla.loc['2010-01-01':'2024-09-01'].index

# %%
index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2024-07-11', '2024-07-12', '2024-07-15', '2024-07-16',
#                '2024-07-17', '2024-07-18', '2024-07-19', '2024-07-22',
#                '2024-07-23', '2024-07-24'],
#               dtype='datetime64[ns]', name='Date', length=3541, freq=None)

# %%
share_open = df_tesla.loc['2010-01-01':'2024-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2010-06-29      1.266667
# 2010-06-30      1.719333
# 2010-07-01      1.666667
# 2010-07-02      1.533333
# 2010-07-06      1.333333
#                  ...
# 2024-07-18    251.089996
# 2024-07-19    247.789993
# 2024-07-22    244.210007
# 2024-07-23    253.600006
# 2024-07-24    225.419998
# Name: Open, Length: 3541, dtype: float64

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, axis = plt.subplots()
plt.tight_layout()

# Preventing overlapping
figure.autofmt_xdate()  # It will format the x_axis labels automatically by resizing them
axis.plot(index, share_open)
