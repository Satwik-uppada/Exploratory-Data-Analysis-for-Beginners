# %% [markdown]
# ---
#
# <center><h1>📍 📍 SciPy 📍 📍</h1></center>
#
# ---
#
# ***SciPy is a open source scientific library for python. The SciPy library depends on NumPy, which provides convenient and fast N-dimensional array manipulation.***
#
# ---

# %%
# import the scipy library
import scipy

# %% [markdown]
# ***If you got an error while running the above cell, import it by using the following command***
#
# ***`!pip3 install scipy`***
#
# ---

# %%
# check the version of scipy
scipy.__version__
# Out:
# '1.10.0'

# %% [markdown]
# #### `COMPUTE THE Nth DERIVATE OF A FUNCTION`
#
# ---

# %%
# import the derivative from scipy
from scipy.misc import derivative

# %%
# define the function
def my_function(x):
    return x**2 + x + 1

# calculate the first derivative of the function at x = 2

derivative(func= my_function, x0=2)
# Out:
# C:\Users\uppada satwik\AppData\Local\Temp\ipykernel_14236\2341465271.py:7: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   derivative(func= my_function, x0=2)
# 5.0

# %% [markdown]
# #### Function: `f(x) = x**2 + x + 1`
# #### Derivate:  `f'(x) = 2*x + 1`
# #### Solution:  `f'(2) = 2*2 + 1 = 5`
#
# ---
#
# ***Now, calculate the second derivative***
#
# ---

# %%
derivative(func=my_function,x0=2,n=2)
# Out:
# C:\Users\uppada satwik\AppData\Local\Temp\ipykernel_14236\564623337.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   derivative(func=my_function,x0=2,n=2)
# 2.0

# %% [markdown]
# ---
#
# #### `PERMUTATION AND COMBINATIONS`
#
# ---

# %%
# COMBINATIONS
from scipy.special import comb

# total number of combinations from 4 different values taken 2 at a time
# Value of 4C2
com = comb(4, 2)

print(com)
# Out:
# 6.0

# %%
# PERMUTATIONS: Value of 4P2
from scipy.special import perm
per = perm(4, 2)

print(per)
# Out:
# 12.0

# %% [markdown]
# ---
#
#
# #### `LINEAR ALGEBRA`
#
#
#
# ---

# %%
# import linear algebra module and numpy
from scipy import linalg
import numpy as np

# %%
# square matrix
matrix = np.array([[1, 5, 2],
                   [3, 2, 1],
                   [1, 2, 1]])

# %%
matrix
# Out:
# array([[1, 5, 2],
#        [3, 2, 1],
#        [1, 2, 1]])

# %%
# pass values to det() function
linalg.det(matrix)
# Out:
# -2.0

# %%
# inverse of a matrix
linalg.inv(matrix)
# Out:
# array([[ 2.77555756e-17,  5.00000000e-01, -5.00000000e-01],
#        [ 1.00000000e+00,  5.00000000e-01, -2.50000000e+00],
#        [-2.00000000e+00, -1.50000000e+00,  6.50000000e+00]])

# %% [markdown]
# ***Learn more about SciPy here: https://docs.scipy.org/doc/***
#
# ---
